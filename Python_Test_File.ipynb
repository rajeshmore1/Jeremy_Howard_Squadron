# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeshmore1/Jeremy_Howard_Squadron/blob/main/Python_Test_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Python Tutorial 1
#
# ## Index
#
# ### Index 2
#
#
# This is the first session of Machine Learning.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""jbdjcdbc"""
# Out:
# 'jbdjcdbc'

# %%
a = 3+3

# %%
a = 4+3

# %%
print(a)
